# %%
import numpy as np
import pandas as pd

# %%
bee_df = pd.read_csv("data/bee_images/bee_data.csv")

# %%
bee_df.columns
# Out:
# Index(['file', 'date', 'time', 'location', 'zip code', 'subspecies', 'health',
#        'pollen_carrying', 'caste'],
#       dtype='object')

# %%
location = pd.read_csv('us-zip-code-latitude-and-longitude.csv', sep = ';')

# %%
location.head(2)
# Out:
#      Zip          City State   Latitude  Longitude  Timezone  \
# 0  55795  Willow River    MN  46.317812  -92.84315        -6
# 1  45388     Yorkshire    OH  40.328535  -84.47938        -5
#
#    Daylight savings time flag             geopoint
# 0                           1  46.317812,-92.84315
# 1                           1  40.328535,-84.47938

# %%
location.columns
# Out:
# Index(['Zip', 'City', 'State', 'Latitude', 'Longitude', 'Timezone',
#        'Daylight savings time flag', 'geopoint'],
#       dtype='object')

# %%
bee_full = bee_df.merge(location, how = "left", left_on = 'zip code', right_on = 'Zip')

# %%
bee_full
# Out:
#              file     date   time           location  zip code subspecies  \
# 0     041_066.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 1     041_072.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 2     041_073.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 3     041_067.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# 4     041_059.png  8/28/18  16:07     Alvin, TX, USA     77511         -1
# ...           ...      ...    ...                ...       ...        ...
# 5167  027_011.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5168  027_007.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5169  027_013.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5170  027_012.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
# 5171  027_014.png  8/20/18  10:03  San Jose, CA, USA     95124         -1
#
#                  health  pollen_carrying   caste    Zip      City State  \
# ...

# %%
bee_full = bee_full.drop_duplicates(subset='zip code', keep="first")
bee_full
# Out:
#              file     date   time              location  zip code  \
# 0     041_066.png  8/28/18  16:07        Alvin, TX, USA     77511
# 74    017_029.png   8/6/18  13:21     Saratoga, CA, USA     95070
# 514   036_094.png  8/21/18  15:56       Athens, GA, USA     30607
# 540   029_004.png  8/20/18   9:53     San Jose, CA, USA     95124
# 553   008_127.png  8/16/18   8:20  New Orleans, LA, USA     70115
# 1167  011_027.png  8/19/18  18:30   Des Moines, IA, USA     50315
# 1943  002_024.png  8/25/18  14:00        Keene, NH, USA      3431
#
#                  subspecies                    health  pollen_carrying  \
# 0                        -1         hive being robbed            False
# 74        Italian honey bee                   healthy            False
# 514       Italian honey bee  few varrao, hive beetles            False
# 540                      -1                   healthy            False
# 553   VSH Italian honey bee                   healthy            False
# ...

# %%
urls = np.array("https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/001_043.png", 
        "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/017_029.png",
        "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/036_094.png",
        "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/029_004.png",
        "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/008_127.png",
        "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/011_027.png",
        "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/002_024.png"])



urls
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-a34e610b68ec> in <module>
# ----> 1 urls = np.array("https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/001_043.png",
#       2         "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/017_029.png",
#       3         "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/036_094.png",
#       4         "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/029_004.png",
#       5         "https://github.com/JuliaWood1/DH151/blob/main/Week%204/data/bee_images/bee_imgs/bee_imgs/008_127.png",
#
# ValueError: only 2 non-keyword arguments accepted

# %%
bee_full['html_url']

# %%
bee_full.to_csv('bee_full.csv')

# %%
bee_full.iloc[0:999, :].to_csv('bee_full.csv')

# %%
bee_full.iloc[0:999, :]
# Out:
#             file     date   time        location  zip code         subspecies  \
# 0    041_066.png  8/28/18  16:07  Alvin, TX, USA     77511                 -1
# 1    041_072.png  8/28/18  16:07  Alvin, TX, USA     77511                 -1
# 2    041_073.png  8/28/18  16:07  Alvin, TX, USA     77511                 -1
# 3    041_067.png  8/28/18  16:07  Alvin, TX, USA     77511                 -1
# 4    041_059.png  8/28/18  16:07  Alvin, TX, USA     77511                 -1
# ..           ...      ...    ...             ...       ...                ...
# 994  030_857.png  8/17/18  17:50  Alvin, TX, USA     77511  Italian honey bee
# 995  030_843.png  8/17/18  17:50  Alvin, TX, USA     77511  Italian honey bee
# 996  030_670.png  8/17/18  17:50  Alvin, TX, USA     77511  Italian honey bee
# 997  030_664.png  8/17/18  17:50  Alvin, TX, USA     77511  Italian honey bee
# 998  030_880.png  8/17/18  17:50  Alvin, TX, USA     77511  Italian honey bee
#
# ...
